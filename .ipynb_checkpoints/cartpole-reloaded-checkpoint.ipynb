# %%
from pct.putils import FunctionsList

# %%
from pct.hierarchy import PCTHierarchy
cartpole_hierarchy = PCTHierarchy.load("cartpole5-full.json")

# %%
cartpole = FunctionsList.getInstance().get_function("CartPole-v1")
cartpole.render=True
cartpole_hierarchy.set_order("Down")
#cartpole_hierarchy.draw(font_size=10, figsize=(8,12), move={'CartPole-v1': [-0.075, 0]}, node_size=1000)

# %%
cartpole_hierarchy.clear_values()
cartpole_hierarchy.summary()
#FunctionsList.getInstance().clear()
FunctionsList.getInstance().report()
# Out:
# cartpoleh PCTHierarchy
# **************************
# PRE: CartPole-v1 OpenAIGym | 0 | links  greaterthan
# Level 4
# pole_position_node PCTNode
# ----------------------------
# REF: pole_position_reference Constant | 0
# PER: pole_position IndexedParameter | index 4 | 0 | links  CartPole-v1
# COM: subtract4 Subtract | 0 | links  pole_position_reference pole_position
# OUT: pole_position_output Sigmoid | range 0.45 scale 2  | 0 | links  subtract4
# ----------------------------
# Level 3
# pole_angle_node PCTNode
# ----------------------------
# REF: pole_angle_reference PassOn | 0 | links  pole_position_output
# PER: pole_angle IndexedParameter | index 2 | 0 | links  CartPole-v1
# COM: subtract3 Subtract | 0 | links  pole_angle_reference pole_angle
# OUT: pole_angle_output Proportional | gain 2 | 0 | links  subtract3
# ----------------------------
# Level 2
# pole_velocity_node PCTNode
# ----------------------------
# REF: pole_velocity_reference PassOn | 0 | links  pole_angle_output
# PER: pole_velocity IndexedParameter | index 3 | 0 | links  CartPole-v1
# COM: subtract2 Subtract | 0 | links  pole_velocity_reference pole_velocity
# OUT: pole_velocity_output PassOn | 0 | links  subtract2
# ----------------------------
# Level 1
# cart_position_node PCTNode
# ----------------------------
# REF: cart_position_reference IntegrationDual | gain 90 slow 100  | 0 | links  pole_velocity_output cart_position
# PER: cart_position IndexedParameter | index 0 | 0 | links  CartPole-v1
# COM: subtract1 Subtract | 0 | links  cart_position_reference cart_position
# OUT: cart_position_output Proportional | gain 2 | 0 | links  subtract1
# ----------------------------
# Level 0
# cart_velocity_node PCTNode
# ----------------------------
# REF: cart_velocity_reference PassOn | 0 | links  cart_position_output
# PER: cart_velocity IndexedParameter | index 1 | 0 | links  CartPole-v1
# COM: subtract Subtract | 0 | links  cart_velocity_reference cart_velocity
# OUT: force Integration | gain -0.1 slow 4  | 0 | links  subtract
# ----------------------------
# POST: greaterthan GreaterThan | threshold 0 upper 1 lower 0  | 0 | links  force
# **************************
# 27
# ***  CartPole-v1 [<pct.functions.OpenAIGym object at 0x0000020F6259A988>]
# {'value': 0, 'links': ['greaterthan'], 'checklinks': True, 'name': 'CartPole-v1', 'decimal_places': 3, 'video_wrap': False, 'env_name': 'CartPole-v1', 'env': <TimeLimit<CartPoleEnv<CartPole-v1>>>, 'render': True, 'reward': 0, 'done': False, 'info': {}}
# ***  greaterthan [<pct.functions.GreaterThan object at 0x0000020F62A9DF88>]
# {'value': 0, 'links': ['force'], 'checklinks': True, 'name': 'greaterthan', 'decimal_places': 3, 'threshold': 0, 'upper': 1, 'lower': 0}
# ***  cart_velocity_node [<pct.nodes.PCTNode object at 0x0000020F62A92108>]
# <pct.nodes.PCTNode object at 0x0000020F62A92108>
# ***  cart_velocity_reference [<pct.functions.PassOn object at 0x0000020F62A82A48>]
# {'value': 0, 'links': ['cart_position_output'], 'checklinks': True, 'name': 'cart_velocity_reference', 'decimal_places': 3}
# ***  cart_velocity [<pct.functions.IndexedParameter object at 0x0000020F6244D808>]
# {'value': 0, 'links': [<pct.functions.OpenAIGym object at 0x0000020F6259A988>], 'checklinks': True, 'name': 'cart_velocity', 'decimal_places': 3, 'index': 1}
# ***  subtract [<pct.functions.Subtract object at 0x0000020F62A82C08>]
# {'value': 0, 'links': [<pct.functions.PassOn object at 0x0000020F62A82A48>, <pct.functions.IndexedParameter object at 0x0000020F6244D808>], 'checklinks': True, 'name': 'subtract', 'decimal_places': 3}
# ***  force [<pct.functions.Integration object at 0x0000020F6CE009C8>]
# {'value': 0, 'links': [<pct.functions.Subtract object at 0x0000020F62A82C08>], 'checklinks': True, 'name': 'force', 'decimal_places': 3, 'gain': -0.1, 'slow': 4}
# ***  cart_position_node [<pct.nodes.PCTNode object at 0x0000020F6CE00F08>]
# <pct.nodes.PCTNode object at 0x0000020F6CE00F08>
# ***  cart_position_reference [<pct.functions.IntegrationDual object at 0x0000020F62A82088>]
# {'value': 0, 'links': ['pole_velocity_output', 'cart_position'], 'checklinks': True, 'name': 'cart_position_reference', 'decimal_places': 3, 'gain': 90, 'slow': 100}
# ***  cart_position [<pct.functions.IndexedParameter object at 0x0000020F6CE005C8>]
# {'value': 0, 'links': [<pct.functions.OpenAIGym object at 0x0000020F6259A988>], 'checklinks': True, 'name': 'cart_position', 'decimal_places': 3, 'index': 0}
# ***  subtract1 [<pct.functions.Subtract object at 0x0000020F62A82608>]
# {'value': 0, 'links': [<pct.functions.IntegrationDual object at 0x0000020F62A82088>, <pct.functions.IndexedParameter object at 0x0000020F6CE005C8>], 'checklinks': True, 'name': 'subtract1', 'decimal_places': 3}
# ***  cart_position_output [<pct.functions.Proportional object at 0x0000020F6CE00B08>]
# {'value': 0, 'links': [<pct.functions.Subtract object at 0x0000020F62A82608>], 'checklinks': True, 'name': 'cart_position_output', 'decimal_places': 3, 'gain': 2}
# ***  pole_velocity_node [<pct.nodes.PCTNode object at 0x0000020F6CE00E88>]
# <pct.nodes.PCTNode object at 0x0000020F6CE00E88>
# ***  pole_velocity_reference [<pct.functions.PassOn object at 0x0000020F62A82FC8>]
# {'value': 0, 'links': ['pole_angle_output'], 'checklinks': True, 'name': 'pole_velocity_reference', 'decimal_places': 3}
# ***  pole_velocity [<pct.functions.IndexedParameter object at 0x0000020F6CE00F48>]
# {'value': 0, 'links': [<pct.functions.OpenAIGym object at 0x0000020F6259A988>], 'checklinks': True, 'name': 'pole_velocity', 'decimal_places': 3, 'index': 3}
# ***  subtract2 [<pct.functions.Subtract object at 0x0000020F62A82C88>]
# {'value': 0, 'links': [<pct.functions.PassOn object at 0x0000020F62A82FC8>, <pct.functions.IndexedParameter object at 0x0000020F6CE00F48>], 'checklinks': True, 'name': 'subtract2', 'decimal_places': 3}
# ***  pole_velocity_output [<pct.functions.PassOn object at 0x0000020F6CE00E08>]
# {'value': 0, 'links': [<pct.functions.Subtract object at 0x0000020F62A82C88>], 'checklinks': True, 'name': 'pole_velocity_output', 'decimal_places': 3}
# ***  pole_angle_node [<pct.nodes.PCTNode object at 0x0000020F6CE00148>]
# <pct.nodes.PCTNode object at 0x0000020F6CE00148>
# ***  pole_angle_reference [<pct.functions.PassOn object at 0x0000020F62A82748>]
# {'value': 0, 'links': ['pole_position_output'], 'checklinks': True, 'name': 'pole_angle_reference', 'decimal_places': 3}
# ***  pole_angle [<pct.functions.IndexedParameter object at 0x0000020F62A921C8>]
# {'value': 0, 'links': [<pct.functions.OpenAIGym object at 0x0000020F6259A988>], 'checklinks': True, 'name': 'pole_angle', 'decimal_places': 3, 'index': 2}
# ***  subtract3 [<pct.functions.Subtract object at 0x0000020F62A82D48>]
# {'value': 0, 'links': [<pct.functions.PassOn object at 0x0000020F62A82748>, <pct.functions.IndexedParameter object at 0x0000020F62A921C8>], 'checklinks': True, 'name': 'subtract3', 'decimal_places': 3}
# ***  pole_angle_output [<pct.functions.Proportional object at 0x0000020F62A92548>]
# {'value': 0, 'links': [<pct.functions.Subtract object at 0x0000020F62A82D48>], 'checklinks': True, 'name': 'pole_angle_output', 'decimal_places': 3, 'gain': 2}
# ***  pole_position_node [<pct.nodes.PCTNode object at 0x0000020F62A92588>]
# <pct.nodes.PCTNode object at 0x0000020F62A92588>
# ***  pole_position_reference [<pct.functions.Constant object at 0x0000020F62A82D08>]
# {'value': 0, 'links': [], 'checklinks': True, 'name': 'pole_position_reference', 'decimal_places': 3}
# ***  pole_position [<pct.functions.IndexedParameter object at 0x0000020F62A92B48>]
# {'value': 0, 'links': [<pct.functions.OpenAIGym object at 0x0000020F6259A988>], 'checklinks': True, 'name': 'pole_position', 'decimal_places': 3, 'index': 4}
# ***  subtract4 [<pct.functions.Subtract object at 0x0000020F62A823C8>]
# {'value': 0, 'links': [<pct.functions.Constant object at 0x0000020F62A82D08>, <pct.functions.IndexedParameter object at 0x0000020F62A92B48>], 'checklinks': True, 'name': 'subtract4', 'decimal_places': 3}
# ***  pole_position_output [<pct.functions.Sigmoid object at 0x0000020F62A92C08>]
# {'value': 0, 'links': [<pct.functions.Subtract object at 0x0000020F62A823C8>], 'checklinks': True, 'name': 'pole_position_output', 'decimal_places': 3, 'range': 0.45, 'scale': 2}

# %%
cartpole_hierarchy.run(100, verbose=True)
FunctionsList.getInstance().get_function("pole_position_reference").set_value(2)
cartpole_hierarchy.run(400)
# Out:
# 0.048 -0.242 -0.039 0.284 0.048 -0.242 -0.039 0.284 1.0 False {}
# pole_position_node 0.000 0.048 -0.048 -0.024
# pole_angle_node -0.024 -0.039 0.015 0.031
# pole_velocity_node 0.031 0.284 -0.253 -0.253
# cart_position_node -0.228 0.048 -0.275 -0.551
# cart_velocity_node -0.551 -0.242 -0.309 0.008
# 1.000
#
# 0.043 -0.047 -0.033 -0.021 0.043 -0.047 -0.033 -0.021 1.0 False {}
# pole_position_node 0.000 0.043 -0.043 -0.021
# pole_angle_node -0.021 -0.033 0.012 0.024
# pole_velocity_node 0.024 -0.021 0.045 0.045
# cart_position_node 0.088 0.043 0.045 0.090
# cart_velocity_node 0.090 -0.047 0.136 0.002
# 1.000
#
# 0.042 0.149 -0.034 -0.324 0.042 0.149 -0.034 -0.324 1.0 False {}
# pole_position_node 0.000 0.042 -0.042 -0.021
# pole_angle_node -0.021 -0.034 0.013 0.026
# pole_velocity_node 0.026 -0.324 0.350 0.350
# cart_position_node 0.357 0.042 0.315 0.631
# cart_velocity_node 0.631 0.149 0.482 -0.010
# 0.000
#
# 0.045 -0.046 -0.040 -0.042 0.045 -0.046 -0.040 -0.042 1.0 False {}
# pole_position_node 0.000 0.045 -0.045 -0.022
# pole_angle_node -0.022 -0.040 0.018 0.036
# pole_velocity_node 0.036 -0.042 0.078 0.078
# cart_position_node 0.112 0.045 0.067 0.133
# cart_velocity_node 0.133 -0.046 0.179 -0.012
# 0.000
#
# 0.044 -0.240 -0.041 0.238 0.044 -0.240 -0.041 0.238 1.0 False {}
# pole_position_node 0.000 0.044 -0.044 -0.022
# pole_angle_node -0.022 -0.041 0.019 0.038
# pole_velocity_node 0.038 0.238 -0.199 -0.199
# cart_position_node -0.135 0.044 -0.179 -0.358
# cart_velocity_node -0.358 -0.240 -0.118 -0.006
# 0.000
#
# 0.039 -0.435 -0.036 0.517 0.039 -0.435 -0.036 0.517 1.0 False {}
# pole_position_node 0.000 0.039 -0.039 -0.019
# pole_angle_node -0.019 -0.036 0.017 0.034
# pole_velocity_node 0.034 0.517 -0.483 -0.483
# cart_position_node -0.392 0.039 -0.431 -0.861
# cart_velocity_node -0.861 -0.435 -0.427 0.006
# 1.000
#
# 0.030 -0.239 -0.026 0.213 0.030 -0.239 -0.026 0.213 1.0 False {}
# pole_position_node 0.000 0.030 -0.030 -0.015
# pole_angle_node -0.015 -0.026 0.011 0.022
# pole_velocity_node 0.022 0.213 -0.192 -0.192
# cart_position_node -0.134 0.030 -0.164 -0.328
# cart_velocity_node -0.328 -0.239 -0.089 0.007
# 1.000
#
# 0.026 -0.043 -0.022 -0.088 0.026 -0.043 -0.022 -0.088 1.0 False {}
# pole_position_node 0.000 0.026 -0.026 -0.013
# pole_angle_node -0.013 -0.022 0.009 0.018
# pole_velocity_node 0.018 -0.088 0.105 0.105
# cart_position_node 0.125 0.026 0.099 0.199
# cart_velocity_node 0.199 -0.043 0.242 -0.001
# 0.000
#
# 0.025 -0.238 -0.024 0.198 0.025 -0.238 -0.024 0.198 1.0 False {}
# pole_position_node 0.000 0.025 -0.025 -0.012
# pole_angle_node -0.012 -0.024 0.011 0.022
# pole_velocity_node 0.022 0.198 -0.176 -0.176
# cart_position_node -0.133 0.025 -0.158 -0.315
# cart_velocity_node -0.315 -0.238 -0.077 0.001
# 1.000
#
# 0.020 -0.043 -0.020 -0.102 0.020 -0.043 -0.020 -0.102 1.0 False {}
# pole_position_node 0.000 0.020 -0.020 -0.010
# pole_angle_node -0.010 -0.020 0.010 0.019
# pole_velocity_node 0.019 -0.102 0.121 0.121
# cart_position_node 0.133 0.020 0.113 0.227
# cart_velocity_node 0.227 -0.043 0.270 -0.006
# 0.000
#
# 0.019 -0.238 -0.022 0.185 0.019 -0.238 -0.022 0.185 1.0 False {}
# pole_position_node 0.000 0.019 -0.019 -0.010
# pole_angle_node -0.010 -0.022 0.012 0.024
# pole_velocity_node 0.024 0.185 -0.161 -0.161
# cart_position_node -0.125 0.019 -0.144 -0.288
# cart_velocity_node -0.288 -0.238 -0.050 -0.003
# 0.000
#
# 0.014 -0.432 -0.018 0.470 0.014 -0.432 -0.018 0.470 1.0 False {}
# pole_position_node 0.000 0.014 -0.014 -0.007
# pole_angle_node -0.007 -0.018 0.011 0.021
# pole_velocity_node 0.021 0.470 -0.449 -0.449
# cart_position_node -0.385 0.014 -0.400 -0.799
# cart_velocity_node -0.799 -0.432 -0.367 0.007
# 1.000
#
# 0.006 -0.237 -0.008 0.172 0.006 -0.237 -0.008 0.172 1.0 False {}
# pole_position_node 0.000 0.006 -0.006 -0.003
# pole_angle_node -0.003 -0.008 0.006 0.011
# pole_velocity_node 0.011 0.172 -0.161 -0.161
# cart_position_node -0.131 0.006 -0.136 -0.273
# cart_velocity_node -0.273 -0.237 -0.036 0.006
# 1.000
#
# 0.001 -0.042 -0.005 -0.123 0.001 -0.042 -0.005 -0.123 1.0 False {}
# pole_position_node 0.000 0.001 -0.001 -0.000
# pole_angle_node -0.000 -0.005 0.005 0.009
# pole_velocity_node 0.009 -0.123 0.132 0.132
# cart_position_node 0.125 0.001 0.124 0.247
# cart_velocity_node 0.247 -0.042 0.289 -0.003
# 0.000
#
# 0.000 -0.237 -0.007 0.168 0.000 -0.237 -0.007 0.168 1.0 False {}
# pole_position_node 0.000 0.000 -0.000 -0.000
# pole_angle_node -0.000 -0.007 0.007 0.015
# pole_velocity_node 0.015 0.168 -0.153 -0.153
# cart_position_node -0.137 0.000 -0.137 -0.274
# cart_velocity_node -0.274 -0.237 -0.037 -0.001
# 0.000
#
# -0.005 -0.432 -0.004 0.458 -0.005 -0.432 -0.004 0.458 1.0 False {}
# pole_position_node 0.000 -0.005 0.005 0.002
# pole_angle_node 0.002 -0.004 0.006 0.013
# pole_velocity_node 0.013 0.458 -0.445 -0.445
# cart_position_node -0.401 -0.005 -0.396 -0.792
# cart_velocity_node -0.792 -0.432 -0.360 0.008
# 1.000
#
# -0.013 -0.237 0.005 0.164 -0.013 -0.237 0.005 0.164 1.0 False {}
# pole_position_node 0.000 -0.013 0.013 0.007
# pole_angle_node 0.007 0.005 0.002 0.003
# pole_velocity_node 0.003 0.164 -0.161 -0.161
# cart_position_node -0.149 -0.013 -0.136 -0.272
# cart_velocity_node -0.272 -0.237 -0.036 0.007
# 1.000
#
# -0.018 -0.042 0.008 -0.127 -0.018 -0.042 0.008 -0.127 1.0 False {}
# pole_position_node 0.000 -0.018 0.018 0.009
# pole_angle_node 0.009 0.008 0.001 0.001
# pole_velocity_node 0.001 -0.127 0.128 0.128
# cart_position_node 0.102 -0.018 0.120 0.241
# cart_velocity_node 0.241 -0.042 0.282 -0.002
# 0.000
#
# -0.019 -0.237 0.006 0.168 -0.019 -0.237 0.006 0.168 1.0 False {}
# pole_position_node 0.000 -0.019 0.019 0.009
# pole_angle_node 0.009 0.006 0.004 0.007
# pole_velocity_node 0.007 0.168 -0.161 -0.161
# cart_position_node -0.163 -0.019 -0.144 -0.288
# cart_velocity_node -0.288 -0.237 -0.051 -0.000
# 0.000
#
# -0.024 -0.432 0.009 0.463 -0.024 -0.432 0.009 0.463 1.0 False {}
# pole_position_node 0.000 -0.024 0.024 0.012
# pole_angle_node 0.012 0.009 0.003 0.005
# pole_velocity_node 0.005 0.463 -0.458 -0.458
# cart_position_node -0.431 -0.024 -0.407 -0.814
# cart_velocity_node -0.814 -0.432 -0.382 0.009
# 1.000
#
# -0.032 -0.237 0.018 0.173 -0.032 -0.237 0.018 0.173 1.0 False {}
# pole_position_node 0.000 -0.032 0.032 0.016
# pole_angle_node 0.016 0.018 -0.002 -0.005
# pole_velocity_node -0.005 0.173 -0.178 -0.178
# cart_position_node -0.183 -0.032 -0.151 -0.302
# cart_velocity_node -0.302 -0.237 -0.065 0.009
# 1.000
#
# -0.037 -0.042 0.022 -0.114 -0.037 -0.042 0.022 -0.114 1.0 False {}
# pole_position_node 0.000 -0.037 0.037 0.018
# pole_angle_node 0.018 0.022 -0.003 -0.007
# pole_velocity_node -0.007 -0.114 0.107 0.107
# cart_position_node 0.064 -0.037 0.101 0.202
# cart_velocity_node 0.202 -0.042 0.245 0.000
# 1.000
#
# -0.038 0.152 0.020 -0.399 -0.038 0.152 0.020 -0.399 1.0 False {}
# pole_position_node 0.000 -0.038 0.038 0.019
# pole_angle_node 0.019 0.020 -0.001 -0.001
# pole_velocity_node -0.001 -0.399 0.398 0.398
# cart_position_node 0.322 -0.038 0.359 0.719
# cart_velocity_node 0.719 0.152 0.566 -0.014
# 0.000
#
# -0.035 -0.043 0.012 -0.101 -0.035 -0.043 0.012 -0.101 1.0 False {}
# pole_position_node 0.000 -0.035 0.035 0.017
# pole_angle_node 0.017 0.012 0.006 0.011
# pole_velocity_node 0.011 -0.101 0.112 0.112
# cart_position_node 0.063 -0.035 0.098 0.196
# cart_velocity_node 0.196 -0.043 0.239 -0.016
# 0.000
#
# -0.036 -0.238 0.010 0.196 -0.036 -0.238 0.010 0.196 1.0 False {}
# pole_position_node 0.000 -0.036 0.036 0.018
# pole_angle_node 0.018 0.010 0.008 0.016
# pole_velocity_node 0.016 0.196 -0.179 -0.179
# cart_position_node -0.196 -0.036 -0.160 -0.320
# cart_velocity_node -0.320 -0.238 -0.082 -0.010
# 0.000
#
# -0.040 -0.433 0.014 0.491 -0.040 -0.433 0.014 0.491 1.0 False {}
# pole_position_node 0.000 -0.040 0.040 0.020
# pole_angle_node 0.020 0.014 0.007 0.013
# pole_velocity_node 0.013 0.491 -0.478 -0.478
# cart_position_node -0.466 -0.040 -0.425 -0.850
# cart_velocity_node -0.850 -0.433 -0.417 0.003
# 1.000
#
# -0.049 -0.239 0.023 0.203 -0.049 -0.239 0.023 0.203 1.0 False {}
# pole_position_node 0.000 -0.049 0.049 0.024
# pole_angle_node 0.024 0.023 0.001 0.002
# pole_velocity_node 0.002 0.203 -0.201 -0.201
# cart_position_node -0.221 -0.049 -0.172 -0.343
# cart_velocity_node -0.343 -0.239 -0.105 0.005
# 1.000
#
# -0.054 -0.044 0.027 -0.082 -0.054 -0.044 0.027 -0.082 1.0 False {}
# pole_position_node 0.000 -0.054 0.054 0.027
# pole_angle_node 0.027 0.027 -0.001 -0.001
# pole_velocity_node -0.001 -0.082 0.081 0.081
# cart_position_node 0.024 -0.054 0.078 0.156
# cart_velocity_node 0.156 -0.044 0.200 -0.001
# 0.000
#
# -0.055 -0.239 0.026 0.219 -0.055 -0.239 0.026 0.219 1.0 False {}
# pole_position_node 0.000 -0.055 0.055 0.027
# pole_angle_node 0.027 0.026 0.001 0.003
# pole_velocity_node 0.003 0.219 -0.216 -0.216
# cart_position_node -0.248 -0.055 -0.193 -0.386
# cart_velocity_node -0.386 -0.239 -0.147 0.003
# 1.000
#
# -0.059 -0.044 0.030 -0.065 -0.059 -0.044 0.030 -0.065 1.0 False {}
# pole_position_node 0.000 -0.059 0.059 0.030
# pole_angle_node 0.030 0.030 -0.001 -0.001
# pole_velocity_node -0.001 -0.065 0.064 0.064
# cart_position_node 0.004 -0.059 0.063 0.126
# cart_velocity_node 0.126 -0.044 0.171 -0.002
# 0.000
#
# -0.060 -0.240 0.029 0.237 -0.060 -0.240 0.029 0.237 1.0 False {}
# pole_position_node 0.000 -0.060 0.060 0.030
# pole_angle_node 0.030 0.029 0.001 0.002
# pole_velocity_node 0.002 0.237 -0.234 -0.234
# cart_position_node -0.270 -0.060 -0.209 -0.419
# cart_velocity_node -0.419 -0.240 -0.179 0.003
# 1.000
#
# -0.065 -0.045 0.034 -0.047 -0.065 -0.045 0.034 -0.047 1.0 False {}
# pole_position_node 0.000 -0.065 0.065 0.032
# pole_angle_node 0.032 0.034 -0.001 -0.002
# pole_velocity_node -0.002 -0.047 0.045 0.045
# cart_position_node -0.020 -0.065 0.045 0.091
# cart_velocity_node 0.091 -0.045 0.136 -0.001
# 0.000
#
# -0.066 -0.241 0.033 0.256 -0.066 -0.241 0.033 0.256 1.0 False {}
# pole_position_node 0.000 -0.066 0.066 0.033
# pole_angle_node 0.033 0.033 0.000 0.000
# pole_velocity_node 0.000 0.256 -0.256 -0.256
# cart_position_node -0.295 -0.066 -0.229 -0.457
# cart_velocity_node -0.457 -0.241 -0.216 0.004
# 1.000
# -0.071 -0.046 0.038 -0.026 -0.071 -0.046 0.038 -0.026 1.0 False {}
# pole_position_node 0.000 -0.071 0.071 0.035
# pole_angle_node 0.035 0.038 -0.003 -0.005
# pole_velocity_node -0.005 -0.026 0.021 0.021
# cart_position_node -0.047 -0.071 0.024 0.049
# cart_velocity_node 0.049 -0.046 0.095 0.001
# 1.000
#
# -0.072 0.148 0.037 -0.307 -0.072 0.148 0.037 -0.307 1.0 False {}
# pole_position_node 0.000 -0.072 0.072 0.036
# pole_angle_node 0.036 0.037 -0.002 -0.003
# pole_velocity_node -0.003 -0.307 0.303 0.303
# cart_position_node 0.203 -0.072 0.275 0.549
# cart_velocity_node 0.549 0.148 0.401 -0.009
# 0.000
#
# -0.069 -0.047 0.031 -0.002 -0.069 -0.047 0.031 -0.002 1.0 False {}
# pole_position_node 0.000 -0.069 0.069 0.034
# pole_angle_node 0.034 0.031 0.003 0.006
# pole_velocity_node 0.006 -0.002 0.009 0.009
# cart_position_node -0.063 -0.069 0.005 0.011
# cart_velocity_node 0.011 -0.047 0.058 -0.008
# 0.000
#
# -0.070 -0.243 0.031 0.300 -0.070 -0.243 0.031 0.300 1.0 False {}
# pole_position_node 0.000 -0.070 0.070 0.035
# pole_angle_node 0.035 0.031 0.004 0.007
# pole_velocity_node 0.007 0.300 -0.293 -0.293
# cart_position_node -0.332 -0.070 -0.262 -0.524
# cart_velocity_node -0.524 -0.243 -0.281 0.001
# 1.000
#
# -0.075 -0.048 0.037 0.017 -0.075 -0.048 0.037 0.017 1.0 False {}
# pole_position_node 0.000 -0.075 0.075 0.037
# pole_angle_node 0.037 0.037 -0.000 -0.000
# pole_velocity_node -0.000 0.017 -0.017 -0.017
# cart_position_node -0.085 -0.075 -0.010 -0.020
# cart_velocity_node -0.020 -0.048 0.028 -0.000
# 0.000
#
# -0.076 -0.244 0.037 0.321 -0.076 -0.244 0.037 0.321 1.0 False {}
# pole_position_node 0.000 -0.076 0.076 0.037
# pole_angle_node 0.037 0.037 0.000 0.000
# pole_velocity_node 0.000 0.321 -0.321 -0.321
# cart_position_node -0.363 -0.076 -0.287 -0.575
# cart_velocity_node -0.575 -0.244 -0.331 0.008
# 1.000
#
# -0.080 -0.049 0.044 0.041 -0.080 -0.049 0.044 0.041 1.0 False {}
# pole_position_node 0.000 -0.080 0.080 0.040
# pole_angle_node 0.040 0.044 -0.004 -0.008
# pole_velocity_node -0.008 0.041 -0.049 -0.049
# cart_position_node -0.119 -0.080 -0.038 -0.076
# cart_velocity_node -0.076 -0.049 -0.027 0.007
# 1.000
#
# -0.081 0.145 0.045 -0.238 -0.081 0.145 0.045 -0.238 1.0 False {}
# pole_position_node 0.000 -0.081 0.081 0.040
# pole_angle_node 0.040 0.045 -0.004 -0.009
# pole_velocity_node -0.009 -0.238 0.229 0.229
# cart_position_node 0.127 -0.081 0.208 0.416
# cart_velocity_node 0.416 0.145 0.271 -0.002
# 0.000
#
# -0.079 -0.051 0.040 0.069 -0.079 -0.051 0.040 0.069 1.0 False {}
# pole_position_node 0.000 -0.079 0.079 0.039
# pole_angle_node 0.039 0.040 -0.001 -0.002
# pole_velocity_node -0.002 0.069 -0.070 -0.070
# cart_position_node -0.144 -0.079 -0.065 -0.131
# cart_velocity_node -0.131 -0.051 -0.080 0.001
# 1.000
#
# -0.080 0.144 0.041 -0.211 -0.080 0.144 0.041 -0.211 1.0 False {}
# pole_position_node 0.000 -0.080 0.080 0.039
# pole_angle_node 0.039 0.041 -0.002 -0.004
# pole_velocity_node -0.004 -0.211 0.208 0.208
# cart_position_node 0.109 -0.080 0.189 0.377
# cart_velocity_node 0.377 0.144 0.233 -0.005
# 0.000
#
# -0.077 -0.052 0.037 0.094 -0.077 -0.052 0.037 0.094 1.0 False {}
# pole_position_node 0.000 -0.077 0.077 0.038
# pole_angle_node 0.038 0.037 0.001 0.002
# pole_velocity_node 0.002 0.094 -0.092 -0.092
# cart_position_node -0.162 -0.077 -0.085 -0.170
# cart_velocity_node -0.170 -0.052 -0.118 -0.001
# 0.000
#
# -0.078 -0.247 0.039 0.398 -0.078 -0.247 0.039 0.398 1.0 False {}
# pole_position_node 0.000 -0.078 0.078 0.038
# pole_angle_node 0.038 0.039 -0.000 -0.001
# pole_velocity_node -0.001 0.398 -0.399 -0.399
# cart_position_node -0.435 -0.078 -0.357 -0.715
# cart_velocity_node -0.715 -0.247 -0.467 0.011
# 1.000
#
# -0.083 -0.053 0.047 0.118 -0.083 -0.053 0.047 0.118 1.0 False {}
# pole_position_node 0.000 -0.083 0.083 0.041
# pole_angle_node 0.041 0.047 -0.006 -0.012
# pole_velocity_node -0.012 0.118 -0.130 -0.130
# cart_position_node -0.194 -0.083 -0.111 -0.222
# cart_velocity_node -0.222 -0.053 -0.170 0.012
# 1.000
#
# -0.084 0.142 0.049 -0.160 -0.084 0.142 0.049 -0.160 1.0 False {}
# pole_position_node 0.000 -0.084 0.084 0.041
# pole_angle_node 0.041 0.049 -0.008 -0.016
# pole_velocity_node -0.016 -0.160 0.144 0.144
# cart_position_node 0.048 -0.084 0.131 0.263
# cart_velocity_node 0.263 0.142 0.121 0.006
# 1.000
#
# -0.081 0.336 0.046 -0.436 -0.081 0.336 0.046 -0.436 1.0 False {}
# pole_position_node 0.000 -0.081 0.081 0.040
# pole_angle_node 0.040 0.046 -0.006 -0.012
# pole_velocity_node -0.012 -0.436 0.424 0.424
# cart_position_node 0.299 -0.081 0.380 0.760
# cart_velocity_node 0.760 0.336 0.424 -0.006
# 0.000
#
# -0.074 0.140 0.037 -0.129 -0.074 0.140 0.037 -0.129 1.0 False {}
# pole_position_node 0.000 -0.074 0.074 0.037
# pole_angle_node 0.037 0.037 -0.001 -0.001
# pole_velocity_node -0.001 -0.129 0.128 0.128
# cart_position_node 0.035 -0.074 0.110 0.219
# cart_velocity_node 0.219 0.140 0.079 -0.006
# 0.000
#
# -0.071 -0.055 0.035 0.175 -0.071 -0.055 0.035 0.175 1.0 False {}
# pole_position_node 0.000 -0.071 0.071 0.035
# pole_angle_node 0.035 0.035 0.001 0.001
# pole_velocity_node 0.001 0.175 -0.173 -0.173
# cart_position_node -0.229 -0.071 -0.158 -0.316
# cart_velocity_node -0.316 -0.055 -0.261 0.002
# 1.000
#
# -0.072 0.139 0.038 -0.107 -0.072 0.139 0.038 -0.107 1.0 False {}
# pole_position_node 0.000 -0.072 0.072 0.036
# pole_angle_node 0.036 0.038 -0.002 -0.005
# pole_velocity_node -0.005 -0.107 0.102 0.102
# cart_position_node 0.021 -0.072 0.094 0.188
# cart_velocity_node 0.188 0.139 0.049 0.000
# 1.000
#
# -0.070 0.334 0.036 -0.387 -0.070 0.334 0.036 -0.387 1.0 False {}
# pole_position_node 0.000 -0.070 0.070 0.035
# pole_angle_node 0.035 0.036 -0.001 -0.003
# pole_velocity_node -0.003 -0.387 0.384 0.384
# cart_position_node 0.274 -0.070 0.344 0.688
# cart_velocity_node 0.688 0.334 0.354 -0.009
# 0.000
#
# -0.063 0.138 0.028 -0.083 -0.063 0.138 0.028 -0.083 1.0 False {}
# pole_position_node 0.000 -0.063 0.063 0.031
# pole_angle_node 0.031 0.028 0.003 0.006
# pole_velocity_node 0.006 -0.083 0.089 0.089
# cart_position_node 0.011 -0.063 0.074 0.149
# cart_velocity_node 0.149 0.138 0.011 -0.007
# 0.000
#
# -0.060 -0.057 0.027 0.218 -0.060 -0.057 0.027 0.218 1.0 False {}
# pole_position_node 0.000 -0.060 0.060 0.030
# pole_angle_node 0.030 0.027 0.003 0.007
# pole_velocity_node 0.007 0.218 -0.211 -0.211
# cart_position_node -0.253 -0.060 -0.192 -0.385
# cart_velocity_node -0.385 -0.057 -0.328 0.003
# 1.000
#
# -0.061 0.137 0.031 -0.066 -0.061 0.137 0.031 -0.066 1.0 False {}
# pole_position_node 0.000 -0.061 0.061 0.031
# pole_angle_node 0.031 0.031 -0.000 -0.001
# pole_velocity_node -0.001 -0.066 0.065 0.065
# cart_position_node -0.001 -0.061 0.060 0.121
# cart_velocity_node 0.121 0.137 -0.017 0.003
# 1.000
#
# -0.059 0.332 0.030 -0.349 -0.059 0.332 0.030 -0.349 1.0 False {}
# pole_position_node 0.000 -0.059 0.059 0.029
# pole_angle_node 0.029 0.030 -0.001 -0.001
# pole_velocity_node -0.001 -0.349 0.348 0.348
# cart_position_node 0.252 -0.059 0.311 0.622
# cart_velocity_node 0.622 0.332 0.290 -0.005
# 0.000
#
# -0.052 0.137 0.023 -0.047 -0.052 0.137 0.023 -0.047 1.0 False {}
# pole_position_node 0.000 -0.052 0.052 0.026
# pole_angle_node 0.026 0.023 0.003 0.006
# pole_velocity_node 0.006 -0.047 0.053 0.053
# cart_position_node -0.010 -0.052 0.042 0.084
# cart_velocity_node 0.084 0.137 -0.053 -0.003
# 0.000
#
# -0.049 -0.059 0.022 0.253 -0.049 -0.059 0.022 0.253 1.0 False {}
# pole_position_node 0.000 -0.049 0.049 0.025
# pole_angle_node 0.025 0.022 0.003 0.006
# pole_velocity_node 0.006 0.253 -0.247 -0.247
# cart_position_node -0.274 -0.049 -0.225 -0.450
# cart_velocity_node -0.450 -0.059 -0.391 0.008
# 1.000
#
# -0.050 0.136 0.027 -0.033 -0.050 0.136 0.027 -0.033 1.0 False {}
# pole_position_node 0.000 -0.050 0.050 0.025
# pole_angle_node 0.025 0.027 -0.002 -0.003
# pole_velocity_node -0.003 -0.033 0.030 0.030
# cart_position_node -0.022 -0.050 0.028 0.056
# cart_velocity_node 0.056 0.136 -0.079 0.008
# 1.000
#
# -0.048 0.331 0.026 -0.317 -0.048 0.331 0.026 -0.317 1.0 False {}
# pole_position_node 0.000 -0.048 0.048 0.024
# pole_angle_node 0.024 0.026 -0.002 -0.005
# pole_velocity_node -0.005 -0.317 0.312 0.312
# cart_position_node 0.231 -0.048 0.279 0.558
# cart_velocity_node 0.558 0.331 0.227 0.000
# 1.000
#
# -0.041 0.525 0.020 -0.601 -0.041 0.525 0.020 -0.601 1.0 False {}
# pole_position_node 0.000 -0.041 0.041 0.021
# pole_angle_node 0.021 0.020 0.001 0.001
# pole_velocity_node 0.001 -0.601 0.603 0.603
# cart_position_node 0.495 -0.041 0.536 1.073
# cart_velocity_node 1.073 0.525 0.547 -0.014
# 0.000
#
# -0.031 0.330 0.008 -0.302 -0.031 0.330 0.008 -0.302 1.0 False {}
# pole_position_node 0.000 -0.031 0.031 0.015
# pole_angle_node 0.015 0.008 0.007 0.015
# pole_velocity_node 0.015 -0.302 0.317 0.317
# cart_position_node 0.245 -0.031 0.276 0.551
# cart_velocity_node 0.551 0.330 0.221 -0.016
# 0.000
#
# -0.024 0.135 0.002 -0.007 -0.024 0.135 0.002 -0.007 1.0 False {}
# pole_position_node 0.000 -0.024 0.024 0.012
# pole_angle_node 0.012 0.002 0.010 0.021
# pole_velocity_node 0.021 -0.007 0.028 0.028
# cart_position_node -0.005 -0.024 0.019 0.037
# cart_velocity_node 0.037 0.135 -0.097 -0.009
# 0.000
#
# -0.021 -0.060 0.002 0.286 -0.021 -0.060 0.002 0.286 1.0 False {}
# pole_position_node 0.000 -0.021 0.021 0.011
# pole_angle_node 0.011 0.002 0.009 0.018
# pole_velocity_node 0.018 0.286 -0.268 -0.268
# cart_position_node -0.265 -0.021 -0.243 -0.487
# cart_velocity_node -0.487 -0.060 -0.427 0.004
# 1.000
#
# -0.023 0.135 0.007 -0.006 -0.023 0.135 0.007 -0.006 1.0 False {}
# pole_position_node 0.000 -0.023 0.023 0.011
# pole_angle_node 0.011 0.007 0.004 0.008
# pole_velocity_node 0.008 -0.006 0.014 0.014
# cart_position_node -0.008 -0.023 0.014 0.028
# cart_velocity_node 0.028 0.135 -0.106 0.005
# 1.000
#
# -0.020 0.330 0.007 -0.297 -0.020 0.330 0.007 -0.297 1.0 False {}
# pole_position_node 0.000 -0.020 0.020 0.010
# pole_angle_node 0.010 0.007 0.003 0.005
# pole_velocity_node 0.005 -0.297 0.302 0.302
# cart_position_node 0.250 -0.020 0.269 0.539
# cart_velocity_node 0.539 0.330 0.209 -0.001
# 0.000
#
# -0.013 0.134 0.001 -0.002 -0.013 0.134 0.001 -0.002 1.0 False {}
# pole_position_node 0.000 -0.013 0.013 0.007
# pole_angle_node 0.007 0.001 0.005 0.011
# pole_velocity_node 0.011 -0.002 0.012 0.012
# cart_position_node -0.008 -0.013 0.005 0.010
# cart_velocity_node 0.010 0.134 -0.125 0.002
# 1.000
#
# -0.011 0.330 0.001 -0.294 -0.011 0.330 0.001 -0.294 1.0 False {}
# pole_position_node 0.000 -0.011 0.011 0.005
# pole_angle_node 0.005 0.001 0.004 0.008
# pole_velocity_node 0.008 -0.294 0.302 0.302
# cart_position_node 0.259 -0.011 0.269 0.539
# cart_velocity_node 0.539 0.330 0.209 -0.004
# 0.000
#
# -0.004 0.134 -0.005 -0.001 -0.004 0.134 -0.005 -0.001 1.0 False {}
# pole_position_node 0.000 -0.004 0.004 0.002
# pole_angle_node 0.002 -0.005 0.007 0.013
# pole_velocity_node 0.013 -0.001 0.014 0.014
# cart_position_node 0.002 -0.004 0.006 0.013
# cart_velocity_node 0.013 0.134 -0.122 0.000
# 1.000
# -0.001 0.330 -0.005 -0.295 -0.001 0.330 -0.005 -0.295 1.0 False {}
# pole_position_node 0.000 -0.001 0.001 0.001
# pole_angle_node 0.001 -0.005 0.005 0.011
# pole_velocity_node 0.011 -0.295 0.306 0.306
# cart_position_node 0.271 -0.001 0.272 0.545
# cart_velocity_node 0.545 0.330 0.215 -0.005
# 0.000
#
# 0.005 0.135 -0.011 -0.004 0.005 0.135 -0.011 -0.004 1.0 False {}
# pole_position_node 0.000 0.005 -0.005 -0.003
# pole_angle_node -0.003 -0.011 0.008 0.016
# pole_velocity_node 0.016 -0.004 0.020 0.020
# cart_position_node 0.016 0.005 0.011 0.022
# cart_velocity_node 0.022 0.135 -0.112 -0.001
# 0.000
#
# 0.008 -0.060 -0.011 0.286 0.008 -0.060 -0.011 0.286 1.0 False {}
# pole_position_node 0.000 0.008 -0.008 -0.004
# pole_angle_node -0.004 -0.011 0.007 0.013
# pole_velocity_node 0.013 0.286 -0.272 -0.272
# cart_position_node -0.240 0.008 -0.248 -0.495
# cart_velocity_node -0.495 -0.060 -0.435 0.010
# 1.000
#
# 0.007 0.135 -0.005 -0.011 0.007 0.135 -0.005 -0.011 1.0 False {}
# pole_position_node 0.000 0.007 -0.007 -0.003
# pole_angle_node -0.003 -0.005 0.002 0.003
# pole_velocity_node 0.003 -0.011 0.014 0.014
# cart_position_node 0.020 0.007 0.013 0.027
# cart_velocity_node 0.027 0.135 -0.108 0.010
# 1.000
#
# 0.009 0.330 -0.005 -0.305 0.009 0.330 -0.005 -0.305 1.0 False {}
# pole_position_node 0.000 0.009 -0.009 -0.005
# pole_angle_node -0.005 -0.005 0.000 0.001
# pole_velocity_node 0.001 -0.305 0.306 0.306
# cart_position_node 0.282 0.009 0.272 0.544
# cart_velocity_node 0.544 0.330 0.214 0.002
# 1.000
#
# 0.016 0.525 -0.011 -0.599 0.016 0.525 -0.011 -0.599 1.0 False {}
# pole_position_node 0.000 0.016 -0.016 -0.008
# pole_angle_node -0.008 -0.011 0.003 0.006
# pole_velocity_node 0.006 -0.599 0.605 0.605
# cart_position_node 0.554 0.016 0.538 1.076
# cart_velocity_node 1.076 0.525 0.551 -0.012
# 0.000
#
# 0.027 0.330 -0.023 -0.310 0.027 0.330 -0.023 -0.310 1.0 False {}
# pole_position_node 0.000 0.027 -0.027 -0.013
# pole_angle_node -0.013 -0.023 0.010 0.020
# pole_velocity_node 0.020 -0.310 0.330 0.330
# cart_position_node 0.313 0.027 0.286 0.572
# cart_velocity_node 0.572 0.330 0.242 -0.015
# 0.000
#
# 0.033 0.136 -0.029 -0.025 0.033 0.136 -0.029 -0.025 1.0 False {}
# pole_position_node 0.000 0.033 -0.033 -0.017
# pole_angle_node -0.017 -0.029 0.013 0.026
# pole_velocity_node 0.026 -0.025 0.050 0.050
# cart_position_node 0.072 0.033 0.038 0.077
# cart_velocity_node 0.077 0.136 -0.059 -0.010
# 0.000
#
# 0.036 -0.059 -0.030 0.259 0.036 -0.059 -0.030 0.259 1.0 False {}
# pole_position_node 0.000 0.036 -0.036 -0.018
# pole_angle_node -0.018 -0.030 0.012 0.024
# pole_velocity_node 0.024 0.259 -0.235 -0.235
# cart_position_node -0.178 0.036 -0.214 -0.428
# cart_velocity_node -0.428 -0.059 -0.369 0.002
# 1.000
#
# 0.035 0.136 -0.025 -0.043 0.035 0.136 -0.025 -0.043 1.0 False {}
# pole_position_node 0.000 0.035 -0.035 -0.017
# pole_angle_node -0.017 -0.025 0.007 0.015
# pole_velocity_node 0.015 -0.043 0.058 0.058
# cart_position_node 0.088 0.035 0.053 0.106
# cart_velocity_node 0.106 0.136 -0.030 0.002
# 1.000
#
# 0.037 0.332 -0.026 -0.344 0.037 0.332 -0.026 -0.344 1.0 False {}
# pole_position_node 0.000 0.037 -0.037 -0.019
# pole_angle_node -0.019 -0.026 0.007 0.014
# pole_velocity_node 0.014 -0.344 0.358 0.358
# cart_position_node 0.356 0.037 0.319 0.638
# cart_velocity_node 0.638 0.332 0.306 -0.006
# 0.000
#
# 0.044 0.137 -0.032 -0.059 0.044 0.137 -0.032 -0.059 1.0 False {}
# pole_position_node 0.000 0.044 -0.044 -0.022
# pole_angle_node -0.022 -0.032 0.011 0.021
# pole_velocity_node 0.021 -0.059 0.080 0.080
# cart_position_node 0.109 0.044 0.065 0.130
# cart_velocity_node 0.130 0.137 -0.007 -0.004
# 0.000
#
# 0.047 -0.058 -0.034 0.223 0.047 -0.058 -0.034 0.223 1.0 False {}
# pole_position_node 0.000 0.047 -0.047 -0.023
# pole_angle_node -0.023 -0.034 0.010 0.021
# pole_velocity_node 0.021 0.223 -0.202 -0.202
# cart_position_node -0.138 0.047 -0.185 -0.371
# cart_velocity_node -0.371 -0.058 -0.313 0.005
# 1.000
#
# 0.046 0.138 -0.029 -0.080 0.046 0.138 -0.029 -0.080 1.0 False {}
# pole_position_node 0.000 0.046 -0.046 -0.023
# pole_angle_node -0.023 -0.029 0.006 0.013
# pole_velocity_node 0.013 -0.080 0.093 0.093
# cart_position_node 0.130 0.046 0.084 0.169
# cart_velocity_node 0.169 0.138 0.031 0.003
# 1.000
#
# 0.048 0.334 -0.031 -0.382 0.048 0.334 -0.031 -0.382 1.0 False {}
# pole_position_node 0.000 0.048 -0.048 -0.024
# pole_angle_node -0.024 -0.031 0.007 0.013
# pole_velocity_node 0.013 -0.382 0.395 0.395
# cart_position_node 0.401 0.048 0.352 0.705
# cart_velocity_node 0.705 0.334 0.371 -0.007
# 0.000
#
# 0.055 0.139 -0.038 -0.099 0.055 0.139 -0.038 -0.099 1.0 False {}
# pole_position_node 0.000 0.055 -0.055 -0.027
# pole_angle_node -0.027 -0.038 0.011 0.022
# pole_velocity_node 0.022 -0.099 0.121 0.121
# cart_position_node 0.157 0.055 0.102 0.204
# cart_velocity_node 0.204 0.139 0.065 -0.007
# 0.000
#
# 0.058 -0.056 -0.040 0.181 0.058 -0.056 -0.040 0.181 1.0 False {}
# pole_position_node 0.000 0.058 -0.058 -0.029
# pole_angle_node -0.029 -0.040 0.012 0.023
# pole_velocity_node 0.023 0.181 -0.158 -0.158
# cart_position_node -0.088 0.058 -0.146 -0.291
# cart_velocity_node -0.291 -0.056 -0.235 0.001
# 1.000
#
# 0.057 0.140 -0.037 -0.124 0.057 0.140 -0.037 -0.124 1.0 False {}
# pole_position_node 0.000 0.057 -0.057 -0.028
# pole_angle_node -0.028 -0.037 0.009 0.017
# pole_velocity_node 0.017 -0.124 0.141 0.141
# cart_position_node 0.184 0.057 0.127 0.255
# cart_velocity_node 0.255 0.140 0.115 -0.002
# 0.000
#
# 0.060 -0.055 -0.039 0.157 0.060 -0.055 -0.039 0.157 1.0 False {}
# pole_position_node 0.000 0.060 -0.060 -0.030
# pole_angle_node -0.030 -0.039 0.010 0.019
# pole_velocity_node 0.019 0.157 -0.138 -0.138
# cart_position_node -0.068 0.060 -0.127 -0.254
# cart_velocity_node -0.254 -0.055 -0.200 0.003
# 1.000
#
# 0.058 0.141 -0.036 -0.148 0.058 0.141 -0.036 -0.148 1.0 False {}
# pole_position_node 0.000 0.058 -0.058 -0.029
# pole_angle_node -0.029 -0.036 0.007 0.014
# pole_velocity_node 0.014 -0.148 0.162 0.162
# cart_position_node 0.205 0.058 0.146 0.293
# cart_velocity_node 0.293 0.141 0.151 -0.001
# 0.000
#
# 0.061 -0.054 -0.039 0.133 0.061 -0.054 -0.039 0.133 1.0 False {}
# pole_position_node 0.000 0.061 -0.061 -0.030
# pole_angle_node -0.030 -0.039 0.009 0.017
# pole_velocity_node 0.017 0.133 -0.116 -0.116
# cart_position_node -0.046 0.061 -0.108 -0.216
# cart_velocity_node -0.216 -0.054 -0.162 0.003
# 1.000
#
# 0.060 0.142 -0.036 -0.172 0.060 0.142 -0.036 -0.172 1.0 False {}
# pole_position_node 0.000 0.060 -0.060 -0.030
# pole_angle_node -0.030 -0.036 0.006 0.013
# pole_velocity_node 0.013 -0.172 0.185 0.185
# cart_position_node 0.227 0.060 0.167 0.333
# cart_velocity_node 0.333 0.142 0.191 -0.003
# 0.000
#
# 0.063 -0.052 -0.040 0.109 0.063 -0.052 -0.040 0.109 1.0 False {}
# pole_position_node 0.000 0.063 -0.063 -0.031
# pole_angle_node -0.031 -0.040 0.009 0.017
# pole_velocity_node 0.017 0.109 -0.092 -0.092
# cart_position_node -0.024 0.063 -0.087 -0.173
# cart_velocity_node -0.173 -0.052 -0.121 0.001
# 1.000
#
# 0.062 0.143 -0.038 -0.196 0.062 0.143 -0.038 -0.196 1.0 False {}
# pole_position_node 0.000 0.062 -0.062 -0.031
# pole_angle_node -0.031 -0.038 0.007 0.014
# pole_velocity_node 0.014 -0.196 0.209 0.209
# cart_position_node 0.251 0.062 0.189 0.377
# cart_velocity_node 0.377 0.143 0.234 -0.005
# 0.000
#
# 0.065 -0.051 -0.042 0.085 0.065 -0.051 -0.042 0.085 1.0 False {}
# pole_position_node 0.000 0.065 -0.065 -0.032
# pole_angle_node -0.032 -0.042 0.009 0.019
# pole_velocity_node 0.019 0.085 -0.066 -0.066
# cart_position_node 0.002 0.065 -0.063 -0.126
# cart_velocity_node -0.126 -0.051 -0.075 -0.002
# 0.000
#
# 0.064 -0.246 -0.040 0.364 0.064 -0.246 -0.040 0.364 1.0 False {}
# pole_position_node 0.000 0.064 -0.064 -0.032
# pole_angle_node -0.032 -0.040 0.008 0.016
# pole_velocity_node 0.016 0.364 -0.348 -0.348
# cart_position_node -0.249 0.064 -0.313 -0.626
# cart_velocity_node -0.626 -0.246 -0.380 0.008
# 1.000
#
# 0.059 -0.050 -0.033 0.059 0.059 -0.050 -0.033 0.059 1.0 False {}
# pole_position_node 0.000 0.059 -0.059 -0.029
# pole_angle_node -0.029 -0.033 0.003 0.007
# pole_velocity_node 0.007 0.059 -0.053 -0.053
# cart_position_node 0.016 0.059 -0.043 -0.086
# cart_velocity_node -0.086 -0.050 -0.036 0.007
# 1.000
#
# 0.058 0.145 -0.031 -0.243 0.058 0.145 -0.031 -0.243 1.0 False {}
# pole_position_node 0.000 0.058 -0.058 -0.029
# pole_angle_node -0.029 -0.031 0.003 0.005
# pole_velocity_node 0.005 -0.243 0.249 0.249
# cart_position_node 0.282 0.058 0.224 0.448
# cart_velocity_node 0.448 0.145 0.303 -0.002
# 0.000
#
# 0.061 -0.049 -0.036 0.039 0.061 -0.049 -0.036 0.039 1.0 False {}
# pole_position_node 0.000 0.061 -0.061 -0.030
# pole_angle_node -0.030 -0.036 0.006 0.012
# pole_velocity_node 0.012 0.039 -0.027 -0.027
# cart_position_node 0.033 0.061 -0.028 -0.056
# cart_velocity_node -0.056 -0.049 -0.006 -0.002
# 0.000
#
# 0.060 -0.244 -0.035 0.320 0.060 -0.244 -0.035 0.320 1.0 False {}
# pole_position_node 0.000 0.060 -0.060 -0.030
# pole_angle_node -0.030 -0.035 0.006 0.011
# pole_velocity_node 0.011 0.320 -0.309 -0.309
# cart_position_node -0.218 0.060 -0.277 -0.555
# cart_velocity_node -0.555 -0.244 -0.311 0.007
# 1.000
#
# 0.055 -0.048 -0.029 0.017 0.055 -0.048 -0.029 0.017 1.0 False {}
# pole_position_node 0.000 0.055 -0.055 -0.027
# pole_angle_node -0.027 -0.029 0.002 0.003
# pole_velocity_node 0.003 0.017 -0.013 -0.013
# cart_position_node 0.048 0.055 -0.007 -0.015
# cart_velocity_node -0.015 -0.048 0.033 0.004
# 1.000
# 1

# %%
cartpole.close()

# %%
cartpole_hierarchy.summary()
# Out:
# cartpoleh PCTHierarchy
# **************************
# PRE: CartPole-v1 OpenAIGym | [ 2.04690912 -0.43007109 -0.03786818  0.41691844  2.04690912 -0.43007109
#  -0.03786818  0.41691844] | links  greaterthan
# Level 4
# pole_position_node PCTNode
# ----------------------------
# REF: pole_position_reference Constant | 2
# PER: pole_position IndexedParameter | index 4 | 2.046909124187765 | links  CartPole-v1
# COM: subtract4 Subtract | -0.04690912418776483 | links  pole_position_reference pole_position
# OUT: pole_position_output Sigmoid | range 0.45 scale 2  | -0.02336997342718905 | links  subtract4
# ----------------------------
# Level 3
# pole_angle_node PCTNode
# ----------------------------
# REF: pole_angle_reference PassOn | -0.02336997342718905 | links  pole_position_output
# PER: pole_angle IndexedParameter | index 2 | -0.037868180328479065 | links  CartPole-v1
# COM: subtract3 Subtract | 0.014498206901290014 | links  pole_angle_reference pole_angle
# OUT: pole_angle_output Proportional | gain 2 | 0.02899641380258003 | links  subtract3
# ----------------------------
# Level 2
# pole_velocity_node PCTNode
# ----------------------------
# REF: pole_velocity_reference PassOn | 0.02899641380258003 | links  pole_angle_output
# PER: pole_velocity IndexedParameter | index 3 | 0.4169184396292565 | links  CartPole-v1
# COM: subtract2 Subtract | -0.38792202582667645 | links  pole_velocity_reference pole_velocity
# OUT: pole_velocity_output PassOn | -0.38792202582667645 | links  subtract2
# ----------------------------
# Level 1
# cart_position_node PCTNode
# ----------------------------
# REF: cart_position_reference IntegrationDual | gain 90 slow 100  | 1.6819741727477955 | links  pole_velocity_output cart_position
# PER: cart_position IndexedParameter | index 0 | 2.046909124187765 | links  CartPole-v1
# COM: subtract1 Subtract | -0.36493495143996935 | links  cart_position_reference cart_position
# OUT: cart_position_output Proportional | gain 2 | -0.7298699028799387 | links  subtract1
# ----------------------------
# Level 0
# cart_velocity_node PCTNode
# ----------------------------
# REF: cart_velocity_reference PassOn | -0.7298699028799387 | links  cart_position_output
# PER: cart_velocity IndexedParameter | index 1 | -0.43007109006579136 | links  CartPole-v1
# COM: subtract Subtract | -0.29979881281414733 | links  cart_velocity_reference cart_velocity
# OUT: force Integration | gain -0.1 slow 4  | 0.003240621982723008 | links  subtract
# ----------------------------
# POST: greaterthan GreaterThan | threshold 0 upper 1 lower 0  | 1 | links  force
# **************************
